# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# ## Building Agentic Applications on Databricks
#
# This course teaches students how to build production-grade agentic applications on Databricks. Students learn to create governed agent tools using Unity Catalog and MCP, build single and multi-agent systems with the OpenAI Agents SDK, and leverage Agent Bricks and Genie for knowledge-assistant use cases. The course covers the full progression from tool prototyping to production deployment, with hands-on experience using MLflow tracing to observe agent execution. Through practical demonstrations and labs, students develop skills in building, orchestrating, and governing AI agents on the Databricks platform.
#
# ---
#
# ## Prerequisites
#
# ### Python-Specific Skills
# - Basic Python syntax and data structures (lists, dictionaries)
# - Understanding of functions, classes, and decorators
# - Experience with Python package management and imports
# - Familiarity with JSON data handling
# - Basic understanding of async/await patterns
#
# ### SQL-Specific Skills
# - Basic SQL query syntax (SELECT, FROM, WHERE)
# - Understanding of SQL functions and user-defined functions
# - Experience with Unity Catalog SQL functions
#
# ### Databricks-Specific Skills
# - Understanding of Databricks workspace navigation and notebook interface
# - Knowledge of Unity Catalog structure (catalogs, schemas, tables, volumes, functions)
# - Experience with Databricks compute resources and serverless computing
# - Familiarity with MLflow experiment tracking
# - Understanding of Databricks model serving endpoints
#
# ### GenAI/Agent-Specific Skills
# - Basic understanding of Large Language Models (LLMs) and their capabilities
# - Knowledge of prompt engineering and system prompts
# - Familiarity with tool-calling agents and function calling concepts
# - Basic awareness of the Model Context Protocol (MCP)
#
# ### Other/Optional Skills
# - Experience with YAML configuration files can be helpful
# - Familiarity with LangChain or the OpenAI SDK can be helpful
# - Basic understanding of REST APIs and HTTP requests can be helpful
#
# ---
#
# ## Course Agenda
#
# The following lessons are part of the **Building Agentic Applications on Databricks** course by **Databricks Academy**.

# %% [markdown]
# | # | Type | Lesson Name |
# |---|------|-------------|
# | 01 | Lecture | [Agents, MCP, and AI Governance on Databricks]($./01 Lecture - Agents, MCP, and AI Governance on Databricks) |
# | 02 | Demo | [Building Agent Tools on Databricks]($./02 Demo - Building Agent Tools on Databricks) |
# | 03 | Lab | [Assessing and Fixing Agent Tools]($./03 Lab - Assessing and Fixing Agent Tools) |
# | 04 | Lecture | [Building Agents with the OpenAI Agents SDK and MLflow]($./04 Lecture - Building Agents with the OpenAI Agents SDK and MLflow) |
# | 05 | Demo | [Building Single Agents with the OpenAI Agents SDK]($./05 Demo - Building Single Agents with the OpenAI Agents SDK) |
# | 06 | Demo | [Multi-Agent Orchestration with the OpenAI Agents SDK]($./06 Demo - Multi-Agent Orchestration with the OpenAI Agents SDK) |
# | 07 | Lecture | [Agent Bricks and Genie]($./07 Lecture - Agent Bricks and Genie) |
# | 08 | Lab | [Building a Supervisor Agent with Agent Bricks]($./08 Lab - Building a Supervisor Agent with Agent Bricks) |
# | 09 | Bonus | [Building Single Agents with LangChain]($./09 Demo - BONUS Building Single Agents with LangChain) |

# %% [markdown]
# ---
#
# ## Requirements
#
# Please review the following requirements before starting the lesson:
#
# * To run demo and lab notebooks, you need to use **Serverless compute (version 5)**, which is enabled by default.
# * This course requires access to Unity Catalog for tool registration and governance.
# * Some demonstrations require model serving endpoints for agent deployment.
#
# The course is structured into three logical sections:
#
# 1. **Foundations (01-03)** introduces agents, MCP, and AI governance on Databricks, then walks through building and assessing agent tools registered to Unity Catalog
# 2. **Agent Development (04-06)** covers building single agents and multi-agent systems using the OpenAI Agents SDK with MLflow tracing
# 3. **Agent Bricks and Beyond (07-09)** explores Agent Bricks, Genie for knowledge assistants, and an alternative LangChain-based approach
#
# Each section combines lectures for conceptual understanding with hands-on demos and labs for practical implementation. The progression moves from tool creation to single agents to multi-agent orchestration, ensuring students build a comprehensive understanding of agentic application development on Databricks.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
