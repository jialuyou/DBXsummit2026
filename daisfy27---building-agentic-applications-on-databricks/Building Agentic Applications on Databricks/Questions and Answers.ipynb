# %% [markdown]
# ## Questions

# %% [markdown]
# 1. What's the main difference between using a function as a tool `tools=[classify_price_tier]` vs a MCP `mcp_servers=[da_mcp_server]`?
#
# 2. What's the main difference between creating an agent with the openai-sdk `Agent()` vs Langchain `create_react_agent`?
